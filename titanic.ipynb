# %%
import pandas as pd
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
file_path = "/content/drive/MyDrive/titanic_study/first_titanic_project/titanic_train.csv"

# %%
titanic_import_df = pd.read_csv(file_path)

# %%
titanic_import_df #불러온 파일 보기  Pclass : 선실 등급  sibsp : 형제자매  Parch : 부모, 자식  Fare : 티켓 요금  cabin : 사물함  Embarked : 출항지
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df= titanic_import_df[['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']] #필요한 X
titanic_label=titanic_import_df['Survived']  # 필요한 y

# %%
titanic_df
# Out:
#      Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         3    male  22.0      1      0   7.2500        S
# 1         1  female  38.0      1      0  71.2833        C
# 2         3  female  26.0      0      0   7.9250        S
# 3         1  female  35.0      1      0  53.1000        S
# 4         3    male  35.0      0      0   8.0500        S
# ..      ...     ...   ...    ...    ...      ...      ...
# 886       2    male  27.0      0      0  13.0000        S
# 887       1  female  19.0      0      0  30.0000        S
# 888       3  female   NaN      1      2  23.4500        S
# 889       1    male  26.0      0      0  30.0000        C
# 890       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 7 columns]

# %%
titanic_df.isna().sum() #결측값 조사
# Out:
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
titanic_df['Age']=titanic_df['Age'].fillna(titanic_df['Age'].mean()) #나이는 중간 값으로 대체
# Out:
# <ipython-input-9-3d08082dfdfc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic_df['Age']=titanic_df['Age'].fillna(titanic_df['Age'].mean()) #나이는 중간 값으로 대체

# %%
titanic_groupbyEmbarked = titanic_df.groupby('Embarked').count()
titanic_groupbyEmbarked
# Out:
#           Pclass  Sex  Age  SibSp  Parch  Fare
# Embarked
# C            168  168  168    168    168   168
# Q             77   77   77     77     77    77
# S            644  644  644    644    644   644

# %%
titanic_df['Embarked'].fillna('S',inplace=True) # 출발지는 제일 많은 S로 대체
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py:6392: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return self._update_inplace(result)

# %%
titanic_df.isna().sum()
# Out:
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
titanic_df['Sex2Num']=titanic_df['Sex'].apply(lambda x : 1 if x == 'male' else 0) #문자열 -> 숫자로 변환 feature encoding하면됨
# Out:
# <ipython-input-13-2d2ac7aebb45>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic_df['Sex2Num']=titanic_df['Sex'].apply(lambda x : 1 if x == 'male' else 0) #문자열 -> 숫자로 변환 feature encoding하면됨

# %%
titanic_df.drop(columns='Sex',inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
titanic_df
# Out:
#      Pclass        Age  SibSp  Parch     Fare Embarked  Sex2Num
# 0         3  22.000000      1      0   7.2500        S        1
# 1         1  38.000000      1      0  71.2833        C        0
# 2         3  26.000000      0      0   7.9250        S        0
# 3         1  35.000000      1      0  53.1000        S        0
# 4         3  35.000000      0      0   8.0500        S        1
# ..      ...        ...    ...    ...      ...      ...      ...
# 886       2  27.000000      0      0  13.0000        S        1
# 887       1  19.000000      0      0  30.0000        S        0
# 888       3  29.699118      1      2  23.4500        S        0
# 889       1  26.000000      0      0  30.0000        C        1
# 890       3  32.000000      0      0   7.7500        Q        1
#
# [891 rows x 7 columns]

# %%
titanic_df['Embarked2Num']= titanic_df['Embarked'].apply(lambda x: 0 if x =='Q' else (1 if x=='C' else 2))
# Out:
# <ipython-input-16-f7672e965db1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic_df['Embarked2Num']= titanic_df['Embarked'].apply(lambda x: 0 if x =='Q' else (1 if x=='C' else 2))

# %%
titanic_df.drop(columns='Embarked',inplace=True)
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
titanic_df
# Out:
#      Pclass        Age  SibSp  Parch     Fare  Sex2Num  Embarked2Num
# 0         3  22.000000      1      0   7.2500        1             2
# 1         1  38.000000      1      0  71.2833        0             1
# 2         3  26.000000      0      0   7.9250        0             2
# 3         1  35.000000      1      0  53.1000        0             2
# 4         3  35.000000      0      0   8.0500        1             2
# ..      ...        ...    ...    ...      ...      ...           ...
# 886       2  27.000000      0      0  13.0000        1             2
# 887       1  19.000000      0      0  30.0000        0             2
# 888       3  29.699118      1      2  23.4500        0             2
# 889       1  26.000000      0      0  30.0000        1             1
# 890       3  32.000000      0      0   7.7500        1             0
#
# [891 rows x 7 columns]

# %%
titanic_data=titanic_df.values

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(titanic_data,titanic_label,test_size=0.2,random_state=1) #데이터 셋 나눔

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(random_state=1) #학습할 모델

# %%
model.fit(X_train,y_train) #학습
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
pred = model.predict(X_test) #예측

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,pred)
# Out:
# 0.7653631284916201

# %%
#추가
